# %%
# !pip3 install rdflib

# %%
import json
import rdflib
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.0 is available.
# You should consider upgrading via the '/Users/siemashko/Public/Studia/IiAD/sem7/SPD/philosearch/env/bin/python3 -m pip install --upgrade pip' command.

# %%
import json
import rdflib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-3a3a30022d9e> in <module>
#       1 import json
# ----> 2 import rdflib
#
# ModuleNotFoundError: No module named 'rdflib'

# %%
with open("philosophers.json", "r") as file:
    philosophers = json.load(file)

# %%
philosophers

# %%
# Out:
# {'people': [{'id': 0,
#    'name': 'Thales',
#    'time': '580 BC',
#    'loc': 'Miletus',
#    'sortby': 'Thales'},
#   {'id': 1,
#    'name': 'Anaximander',
#    'time': '610–546 BC',
#    'loc': 'Miletus',
#    'sortby': 'Anaximander'},
#   {'id': 2,
#    'name': 'Anaximenes',
#    'time': '585–528 BC',
#    'loc': '',
#    'sortby': 'Anaximenes'},
#   {'id': 3,
#    'name': 'Pythagoras',
#    'time': '570–497 BC',
#    'loc': 'Samos',
#    'sortby': 'Pythagoras'},
#   {'id': 4,
#    'name': 'Xenophanes',
#    'time': '570–475 BC',
#    'loc': 'Colophon',
#    'sortby': 'Xenophanes'},
#   {'id': 5,
#    'name': 'Heraclitus',
#    'time': '535–475 BC',
#    'loc': 'Ephesus',
#    'sortby': 'Heraclitus'},
#   {'id': 6,
#    'name': 'Parmenides',
#    'time': '515–460 BC',
#    'loc': '',
#    'sortby': 'Parmenides'},
#   {'id': 7,
#    'name': 'Empedocles',
#    'time': '490–430 BC',
#    'loc': '',
#    'sortby': 'Empedocles'},
#   {'id': 8,
#    'name': 'Leucippus & Democritus',
# ...
